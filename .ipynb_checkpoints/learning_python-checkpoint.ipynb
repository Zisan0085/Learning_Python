# %%
# Task: Create a simple logic gate
birth_year = 2000 # Change this to your birth year
current_year = 2026

age = current_year - birth_year

if age >= 18:
    status = "an Adult"
else:
    status = "a Minor"

print(f"In {current_year}, you are {age} years old.")
print(f"That means you are {status}!")
# Out:
# In 2026, you are 26 years old.
# That means you are an Adult!

# %% [markdown]
# ## Section 1: My First Logic Gate

# %%
import sys

# Test your setup
print("✅ Python is working!")
print(f"✅ Your environment is: {sys.prefix}")

# A simple Python greeting
user_name = "Nazmul"
print(f"Welcome to the world of Python, {user_name}!")
# Out:
# ✅ Python is working!
# ✅ Your environment is: /home/nazmul-hossain-zisan/my_project/jupyter_env
# Welcome to the world of Python, Nazmul!

# %%
# Task: Getting data from the user
your_name = input("Enter your name: ")
favorite_color = input("What is your favorite color? ")

print(f"Hello {your_name}! I bet {favorite_color} looks great on you.")
# Out:
# Hello ZISAN! I bet BLACK looks great on you.

# %%
# Task: Working with Lists
shopping_list = ["Bread", "Milk", "Eggs", "Python Books"]

# Add something new
shopping_list.append("Coffee")

# Print the second item (Python starts counting at 0!)
print(f"Don't forget the {shopping_list[1]}")

# Loop through the whole list
for item in shopping_list:
    print(f"Checking off: {item}")
# Out:
# Don't forget the Milk
# Checking off: Bread
# Checking off: Milk
# Checking off: Eggs
# Checking off: Python Books
# Checking off: Coffee

# %%
# !pip install numpy pandas matplotlib
# Out:
# 397.09s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting numpy
#   Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 66.3 kB/s eta 0:00:00a 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 451.1 kB/s eta 0:00:00:--:--
# Requirement already satisfied: python-dateutil>=2.8.2 in ./jupyter_env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 152.0 kB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in ./jupyter_env/lib/python3.12/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in ./jupyter_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 995.2 kB/s eta 0:00:00:0100:010m
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 1.1 MB/s eta 0:00:0000:0100:01m
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 1.1 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 588.3 kB/s eta 0:00:0000:0100:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 1.0 MB/s eta 0:00:0000:0100:010m
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 222.5 kB/s eta 0:00:0000:0100:01
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 708.4 kB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 914.4 kB/s eta 0:00:00 0:00:01m
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 numpy-2.4.3 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2
